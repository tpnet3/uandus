# %%
import json
import requests

import asyncio
import aiohttp

import pandas as pd
import numpy as np


CLIENT_ID = ""
CLIENT_SECRET = ""
ACCESS_TOKEN = ""
REFRESH_TOKEN = ""
BASE_URL = 'http://www.zumsoon.com/oauth/v1.0/'
ACCESS_TOKEN_URL='http://www.zumsoon.com/oauth/token'


def set_credentials(client_id, client_secret, access_token, refresh_token):
    global ACCESS_TOKEN
    global REFRESH_TOKEN
    global CLIENT_ID
    global CLIENT_SECRET

    ACCESS_TOKEN = access_token
    REFRESH_TOKEN = refresh_token
    CLIENT_ID = client_id
    CLIENT_SECRET = client_secret


def refresh_token():
    
    global ACCESS_TOKEN
    global REFRESH_TOKEN
    global CLIENT_ID
    global CLIENT_SECRET
                  
    data = dict()
    data['grant_type'] = 'refresh_token'
    data['refresh_token'] = REFRESH_TOKEN
    data['client_id'] = CLIENT_ID
    data['client_secret'] = CLIENT_SECRET
    # make custom POST request to get the new token pair
    resp = requests.post(ACCESS_TOKEN_URL, data=data)
    resp = resp.json()
    
    ACCESS_TOKEN = resp['access_token']
    REFRESH_TOKEN = resp['refresh_token']
    
    # checks the response status and parses the new tokens
    # if refresh failed will redirect to login

    return resp

def get_token():
    resp = {'access_token': ACCESS_TOKEN,
           'refresh_token': REFRESH_TOKEN}
    print(resp)

def request(api, method='GET', json=None):
    token = ACCESS_TOKEN
    headers = {"Authorization": "Bearer " + token}
    if method == 'GET':
        resp = requests.get(BASE_URL+api, headers=headers)
        return resp
    
    elif method == 'POST':
        resp = requests.post(BASE_URL+api, headers=headers, json=json)
        return resp
#         if data is not None:
#             resp = requests.post(BASE_URL+api, headers=headers, data=data)
#             return resp
#         elif json is not None:
#             resp = requests.post(BASE_URL+api, headers=headers, json=json)
#             return resp
#         else:
#             return 'data is none.'
        
    else:
        pass

def user_me():
    api = "user/me"
    resp = request(api)
    return resp.json()


def user_client():
    api = "user/client"
    resp = request(api)
    return resp.json()


def user_new_order_messages():
    api = "user/new-order-messages"
    resp = request(api)
    data = resp.json()
    data = json.dumps(data)
    df = pd.read_json(data, orient='records')
    return df

def account():
    api = "account"
    resp = request(api)
    data = resp.json()
    data = json.dumps(data)
    df = pd.read_json(data, orient='records')
    return df


def account_ledger(method='GET', txs=None):
    api = "account/ledger"
    if method == 'GET':
        resp = request(api)
        data = resp.json()
        data = json.dumps(data)
        df = pd.read_json(data, orient='records')
        return df
    elif method == 'POST':
#         txs = json.dumps(txs)
#         resp = request(api, method='POST', data={'txs': txs})
#         return resp.json()
        resp = request(api, method='POST', json=txs)
        return resp.json()
    

def account_report(report_name):
    api = "account/report/{}".format(report_name)
    resp = request(api)
    data = resp.json()
    data = json.dumps(data)
    df = pd.read_json(data, orient='records')
    return df

def account_financial_assets():
    api = "account/financial-assets"
    resp = request(api)
    data = resp.json()
    data = json.dumps(data)
    df = pd.read_json(data, orient='records')
    return df

def broker():
    api = "broker"
    resp = request(api)
    return resp.json()


def broker_current_quote(commodity):
    api = 'broker/current-quote/{}'.format(commodity)
    resp = request(api)
    return resp.json()


def broker_lob(commodity):
    api = 'broker/lob/{}'.format(commodity)
    resp = request(api)
    if resp.status_code == 200:
        lob = resp.json()
        _lob_ask = {int(k): v for k, v in lob['ASK'].items()}
        _lob_bid = {int(k): v for k, v in lob['BID'].items()}

        lob_ask = []
        for key in sorted(_lob_ask.keys()):
            lob_ask.append([key, _lob_ask[key][0], _lob_ask[key][1]])

        lob_bid = []
        for key in sorted(_lob_bid.keys(), reverse=True):
            lob_bid.append([key, _lob_bid[key][0], _lob_bid[key][1]])

        return [lob_ask, lob_bid]
    else:
        return resp.json()

def broker_order(method='GET', order=None):
    """
    order = {'commodity': string, 'quote': integer, 'qty': integer}
            (qty<0 -> ask, qty>0 -> bid)
    Only normal order is allowed, not market order!
    """
    api = 'broker/order'
    if method == 'GET':
        resp = request(api)
        data = resp.json()
        data = json.dumps(data)
        df = pd.read_json(data, orient='records')
        return df
    elif method == 'POST':
        resp = request(api=api, method='POST', json=order)
        return resp.json()

def broker_cancel(cancel):
    api = 'broker/cancel'
    resp = request(api=api, method='POST', json=cancel)
    return resp.json()


def broker_chart(commodity):
    api = "broker/chart/{}".format(commodity)
    resp = request(api)
    if resp.status_code == 200:
        data = resp.json()
        df = pd.DataFrame.from_dict(data)
        return df
    else:
        return resp.json()

# %%
set_credentials(client_id="SPfI9VI4odL4wtAse1DDqylV1nI2RzNW5MPon8SG", 
                client_secret="bM2YkUV4zp26dZIJ73EbeHgKEEUcQTFn3yrBLvpLySdLeoLbd9", 
                access_token="3AL4Ddzscl2UsKjuZByviD2tTHaHOV", 
                refresh_token="YjiyBIvOgIYLozTVRHj501eICneYhC")

# %%
refresh_token()
# Out:
# {'access_token': 'pCWlVqPK6UY4QB7tKIb9TEKq4xPMXx',
#  'refresh_token': '9tijZRD3igEDzP2dqK5XFkKFUueDBx',
#  'scope': 'email address',
#  'token_type': 'Bearer'}

# %%
user_me()
# Out:
# {'email': 'happydhseo@kaist.ac.kr',
#  'first_name': 'Donghyun',
#  'last_name': 'Seo',
#  'username': 'dhseo'}

# %%
user_client()
# Out:
# {'client_id': 'SPfI9VI4odL4wtAse1DDqylV1nI2RzNW5MPon8SG',
#  'client_name': None,
#  'client_scopes': ['email', 'address']}

# %%
user_new_order_messages()
# Out:
#       bid_ask  commodity                             dt     event  \
# 0         ASK       12.0  Mon, 26 Feb 2018 23:41:51 GMT    accept
# 1         ASK       12.0  Mon, 26 Feb 2018 23:41:51 GMT  conclude
# 2         NaN        NaN  Mon, 26 Feb 2018 23:41:51 GMT  complete
# 3         BID       12.0  Mon, 26 Feb 2018 23:41:51 GMT    accept
# 4         BID       12.0  Mon, 26 Feb 2018 23:41:51 GMT  conclude
# 5         ASK       12.0  Mon, 26 Feb 2018 23:41:51 GMT    accept
# 6         BID       12.0  Mon, 26 Feb 2018 23:41:51 GMT  conclude
# 7         NaN        NaN  Mon, 26 Feb 2018 23:41:51 GMT  complete
# 8         ASK       12.0  Mon, 26 Feb 2018 23:41:51 GMT  conclude
# 9         ASK       12.0  Mon, 26 Feb 2018 23:41:51 GMT  conclude
# 10        ASK       12.0  Mon, 26 Feb 2018 23:41:51 GMT  conclude
# 11        NaN        NaN  Mon, 26 Feb 2018 23:41:51 GMT  complete
# 31291  2018-03-08:318   1.0  1400000.0
# 31292  2018-03-08:318   NaN        NaN
# 31293  2018-03-08:319   1.0  1500000.0
# 31294  2018-03-08:320   2.0  2100000.0
#
# [31295 rows x 7 columns]

# %%
account()
# Out:
#     code description                                    name parent_account
# 0   1000          자산                                   asset          ASSET
# 1   1001          현금                                    cash          ASSET
# 2   1002        금융자산                        Financial Assets          ASSET
# 3   2000          부채                               liability      LIABILITY
# 4   3000          자본                                 capital        CAPITAL
# 5   3001       자본잉여금    Additional Paid-in and Other Capital        CAPITAL
# 6   3002        자본조정                     Capital Adjustments        CAPITAL
# 7   3003   기타포괄손익누계액  Accumulated Other Comprehensive Income        CAPITAL
# 8   3004       이익잉여금                       Retained Earnings        CAPITAL
# 9   4000          수익                                  income         INCOME
# 10  4001        금융손익               Financial Profit and Loss         INCOME
# 11  4002       배당금수익         Dividends on Trading Securities         INCOME
# 12  4003        이자수익                       Interest Revenues         INCOME
# 13  5000          비용                                 expense        EXPENSE
# 14  5001          세금                                   taxes        EXPENSE
# 15  5002         수수료                                    fees        EXPENSE
# 16  5003        이자비용                        Interest Expense        EXPENSE

# %%
account_ledger()
# Out:
#        account account_description      account_name account_parent_account  \
# 0         1001                  현금              cash                  ASSET
# 1         3000                  자본           capital                CAPITAL
# 2         1002                금융자산  Financial Assets                  ASSET
# 3         1001                  현금              cash                  ASSET
# 4         5002                 수수료              fees                EXPENSE
# 5         1002                금융자산  Financial Assets                  ASSET
# 6         1001                  현금              cash                  ASSET
# 7         5002                 수수료              fees                EXPENSE
# 8         1001                  현금              cash                  ASSET
# 9         3000                  자본           capital                CAPITAL
# 10        1002                금융자산  Financial Assets                  ASSET
# 11        1001                  현금              cash                  ASSET
# 12        5002                 수수료              fees                EXPENSE
# 13        1002                금융자산  Financial Assets                  ASSET
# 14        1001                  현금              cash                  ASSET
# 15        5002                 수수료              fees                EXPENSE
# 16        1001                  현금              cash                  ASSET
# 17        3000                  자본           capital                CAPITAL
# 18        1002                금융자산  Financial Assets                  ASSET
# 19        1001                  현금              cash                  ASSET
# 20        5002                 수수료              fees                EXPENSE
# 21        1002                금융자산  Financial Assets                  ASSET
# 22        1001                  현금              cash                  ASSET
# 23        5002                 수수료              fees                EXPENSE
# 24        1001                  현금              cash                  ASSET
# 25        3000                  자본           capital                CAPITAL
# 26        1002                금융자산  Financial Assets                  ASSET
# 27        1001                  현금              cash                  ASSET
# 28        5002                 수수료              fees                EXPENSE
# 29        1002                금융자산  Financial Assets                  ASSET
# ...        ...                 ...               ...                    ...
# 35116     1002                금융자산  Financial Assets                  ASSET
# 35117     1001                  현금              cash                  ASSET
# 35118     5002                 수수료              fees                EXPENSE
# 35119     1002                금융자산  Financial Assets                  ASSET
# 35120     1001                  현금              cash                  ASSET
# 35121     5002                 수수료              fees                EXPENSE
# 35122     1002                금융자산  Financial Assets                  ASSET
# 35123     1001                  현금              cash                  ASSET
# 35124     5002                 수수료              fees                EXPENSE
# 35125     1002                금융자산  Financial Assets                  ASSET
# 35126     1001                  현금              cash                  ASSET
# 35127     5002                 수수료              fees                EXPENSE
# 35128     1002                금융자산  Financial Assets                  ASSET
# 35129     1001                  현금              cash                  ASSET
# 35130     5002                 수수료              fees                EXPENSE
# 35131     1002                금융자산  Financial Assets                  ASSET
# 35132     1001                  현금              cash                  ASSET
# 35133     5002                 수수료              fees                EXPENSE
# 35134     1002                금융자산  Financial Assets                  ASSET
# 35135     1001                  현금              cash                  ASSET
# 35136     5002                 수수료              fees                EXPENSE
# 35137     1002                금융자산  Financial Assets                  ASSET
# 35138     1001                  현금              cash                  ASSET
# 35139     5002                 수수료              fees                EXPENSE
# 35140     1002                금융자산  Financial Assets                  ASSET
# 35141     1001                  현금              cash                  ASSET
# 35142     5002                 수수료              fees                EXPENSE
# 35143     1002                금융자산  Financial Assets                  ASSET
# 35144     1001                  현금              cash                  ASSET
# 35145     5002                 수수료              fees                EXPENSE
#
#        commodity commodity_name commodity_unit                             dt  \
# 0              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 1              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 2             12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 3              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 4              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 5             12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 6              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 7              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 8              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 9              1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 10            12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 11             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 12             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 13            12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 14             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 15             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 16             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 17             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 18            12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 19             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 20             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 21            12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 22             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 23             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 24             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 25             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 26            12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# 27             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 28             1            KRW            WON  Thu, 08 Mar 2018 02:06:05 GMT
# 29            12   game_stock_2             EA  Thu, 08 Mar 2018 02:06:05 GMT
# ...          ...            ...            ...                            ...
# 17      3150        1                     1    10000.00   trade test 0
# 18      3151       99                     1        6.00   trade test 1
# 19      3152        1                     1     -594.59   trade test 1
# 20      3153        1                     1        0.59   trade test 1
# 21      3154       99                     1       -6.00   trade test 2
# 22      3155        1                     1      593.41   trade test 2
# 23      3156        1                     1        0.59   trade test 2
# 24      3157        1                     1    10000.00   trade test 0
# 25      3158        1                     1    10000.00   trade test 0
# 26      3159       99                     1        6.00   trade test 1
# 27      3160        1                     1     -594.59   trade test 1
# 28      3161        1                     1        0.59   trade test 1
# 29      3162       99                     1       -6.00   trade test 2
# ...      ...      ...                   ...         ...            ...
# 35116  38249  1700000                     1       -1.00  exchange game
# 35117  38250        1                     1  1698300.00  exchange game
# 35118  38251        1                     1     1700.00  exchange game
# 35119  38252  1700000                     1        1.00  exchange game
# 35120  38253        1                     1 -1701700.00  exchange game
# 35121  38254        1                     1     1700.00  exchange game
# 35122  38255  1700000                     1       -1.00  exchange game
# 35123  38256        1                     1  1698300.00  exchange game
# 35124  38257        1                     1     1700.00  exchange game
# 35125  38258  1700000                     1        1.00  exchange game
# 35126  38259        1                     1 -1701700.00  exchange game
# 35127  38260        1                     1     1700.00  exchange game
# 35128  38261  1600000                     1       -2.00  exchange game
# 35129  38262        1                     1  3196800.00  exchange game
# 35130  38263        1                     1     3200.00  exchange game
# 35131  38264  1600000                     1        2.00  exchange game
# 35132  38265        1                     1 -3203200.00  exchange game
# 35133  38266        1                     1     3200.00  exchange game
# 35134  38267  1400000                     1        1.00  exchange game
# 35135  38268        1                     1 -1401400.00  exchange game
# 35136  38269        1                     1     1400.00  exchange game
# 35137  38270  1400000                     1       -1.00  exchange game
# 35138  38271        1                     1  1398600.00  exchange game
# 35139  38272        1                     1     1400.00  exchange game
# 35140  38273  1400000                     1        1.00  exchange game
# 35141  38274        1                     1 -1401400.00  exchange game
# 35142  38275        1                     1     1400.00  exchange game
# 35143  38276  1400000                     1       -1.00  exchange game
# 35144  38277        1                     1  1398600.00  exchange game
# 35145  38278        1                     1     1400.00  exchange game
#
#        tx_desc_code  tx_id
# 0                10    453
# 1                10    453
# 2                10    453
# 3                10    453
# 4                10    453
# 5                10    453
# 6                10    453
# 7                10    453
# 8                10    454
# 9                10    454
# 10               10    454
# 11               10    454
# 12               10    454
# 13               10    454
# 14               10    454
# 15               10    454
# 16               10    455
# 17               10    455
# 18               10    455
# 19               10    455
# 20               10    455
# 21               10    455
# 22               10    455
# 23               10    455
# 24               10    456
# 25               10    456
# 26               10    456
# 27               10    456
# 28               10    456
# 29               10    456
# ...             ...    ...
# 35116             1   5967
# 35117             1   5967
# 35118             1   5967
# 35119             1   5967
# 35120             1   5967
# 35121             1   5967
# 35122             1   5968
# 35123             1   5968
# 35124             1   5968
# 35125             1   5968
# 35126             1   5968
# 35127             1   5968
# 35128             1   5969
# 35129             1   5969
# 35130             1   5969
# 35131             1   5969
# 35132             1   5969
# 35133             1   5969
# 35134             1   5970
# 35135             1   5970
# 35136             1   5970
# 35137             1   5970
# 35138             1   5970
# 35139             1   5970
# 35140             1   5971
# 35141             1   5971
# 35142             1   5971
# 35143             1   5971
# 35144             1   5971
# 35145             1   5971
#
# [35146 rows x 15 columns]

# %%
txs = [
        {'tx_desc': 'trade test 0',
         'split':
             [
                 {'account': 1001, 'commodity': 1, 'qty': 10000, 'price': 1, 'price_base_commodity': 1},
                 {'account': 3000, 'commodity': 1, 'qty': 10000, 'price': 1, 'price_base_commodity': 1}
             ]
         },
        {'tx_desc': 'trade test 1',
         'split':
             [
                 {'account': 1002, 'commodity': 12, 'qty': 6, 'price': 99, 'price_base_commodity': 1},
                 {'account': 1001, 'commodity': 1, 'qty': -594.59, 'price': 1, 'price_base_commodity': 1},
                 {'account': 5002, 'commodity': 1, 'qty': 0.59, 'price': 1, 'price_base_commodity': 1}
             ]
         },
        {'tx_desc': 'trade test 2',
         'split':
             [
                 {'account': 1002, 'commodity': 12, 'qty': -6, 'price': 99, 'price_base_commodity': 1},
                 {'account': 1001, 'commodity': 1, 'qty': 593.41, 'price': 1, 'price_base_commodity': 1},
                 {'account': 5002, 'commodity': 1, 'qty': 0.59, 'price': 1, 'price_base_commodity': 1}
             ]
         }
    ]

order = {'commodity': 11, 'quote': 1700000, 'qty': -3}
cancel = {'commodity': 11, 'order_id': '2018-03-06:14'}

# %%
account_ledger(method='POST', txs=txs)
# Out:
# {'status': 'accepted'}

# %%
account_report('balance-sheet')
# Out:
#   account     commodity         qty       value
# 0      현금           KRW -20407523.9 -20407523.9
# 1    금융자산  game_stock_1         0.0         0.0
# 2    금융자산  game_stock_2         0.0         0.0
# 3      자본           KRW   1050000.0   1050000.0
# 4     수수료           KRW  21457523.9  21457523.9

# %%
account_financial_assets()
# Out:
#       commodity  qty  value
# 0  game_stock_1    0      0
# 1  game_stock_2    0      0

# %%
broker()
# Out:
# [11, 12]

# %%
broker_order(method='POST', order=order)
# Out:
# 'Order received'

# %%
broker_order()
# Out:
#   bid_ask  commodity  conclusion  init_qty      order_id    quote    status
# 0     ASK         11           0         3  2018-03-12:3  1700000  accepted

# %%
cancel = {'commodity': 11, 'order_id': '2018-03-12:3'}
broker_cancel(cancel)
# Out:
# 'Canceled'

# %%
broker_chart(11)
# Out:
#          close                   dt       high        low       open
# 0    1500000.0  2018-03-06 06:30:00  1500000.0  1500000.0  1500000.0
# 1          NaN  2018-03-06 06:45:00        NaN        NaN        NaN
# 2          NaN  2018-03-06 07:00:00        NaN        NaN        NaN
# 3          NaN  2018-03-06 07:15:00        NaN        NaN        NaN
# 4          NaN  2018-03-06 07:30:00        NaN        NaN        NaN
# 5          NaN  2018-03-06 07:45:00        NaN        NaN        NaN
# 6          NaN  2018-03-06 08:00:00        NaN        NaN        NaN
# 7          NaN  2018-03-06 08:15:00        NaN        NaN        NaN
# 8    1700000.0  2018-03-06 08:30:00  1700000.0  1700000.0  1700000.0
# 9          NaN  2018-03-06 08:45:00        NaN        NaN        NaN
# 10         NaN  2018-03-06 09:00:00        NaN        NaN        NaN
# 11         NaN  2018-03-06 09:15:00        NaN        NaN        NaN
# 12         NaN  2018-03-06 09:30:00        NaN        NaN        NaN
# 13         NaN  2018-03-06 09:45:00        NaN        NaN        NaN
# 14   1600000.0  2018-03-06 10:00:00  1600000.0  1600000.0  1600000.0
